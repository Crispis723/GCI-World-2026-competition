# %% [markdown]
# # Baseline — Versión organizada
#
# **Resumen:** Notebook limpio y estructurado a partir de `baseline_(1).ipynb`.
#
# **Objetivo:** reproducir el flujo: carga de datos → preprocesado → modelado → resultados.

# %% [markdown]
# ## Cómo usar
# - Ejecuta la celda de instalación si necesitas dependencias: `!pip install -r requirements.txt`.
# - Fija el kernel en Python 3.9+ y ejecuta las celdas en orden.
# - Si quieres conservar el original, este archivo se ha guardado como `notebooks/baseline_clean.ipynb`.

# %% [markdown]
# ## Índice
# - [Configuración (dependencias, semilla)](#Configuración)
# - [Carga de datos](#Carga-de-datos)
# - [Preprocesado](#Preprocesado)
# - [Modelado y entrenamiento](#Modelado-y-entrenamiento)
# - [Resultados](#Resultados)
# - [Conclusiones](#Conclusiones)

# %%
# Ejecutar solo si hace falta instalar dependencias en este entorno
# !pip install -r requirements.txt

# %%
# Configuración básica y semilla reproducible
import os
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
print('Entorno listo — semilla fija =', SEED)

# %%
# Importar utilidades del repo (si existen) y comprobar rutas
try:
    from src import run, utils
    print('Imports desde src OK')
except Exception as e:
    print('No se pudieron importar src.run o src.utils:', e)

# Ruta de trabajo
ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
print('Ruta proyecto (aprox):', ROOT)

# %% [markdown]
# ## Carga de datos
# Descripción breve: carga los datos desde la fuente prevista y muestra un vistazo rápido.

# %%
def load_data(path=None):
    """Carga data y devuelve un DataFrame (placeholder).
    Reemplaza la lógica según tus ficheros."""
    if path is None:
        # ejemplo: busca un CSV en data/ o notebooks/
        cand = 'data/dataset.csv'
        if os.path.exists(cand):
            path = cand
        else:
            print('Ruta por defecto no encontrada, devuelve DataFrame vacío')
            return pd.DataFrame()
    return pd.read_csv(path)

# df = load_data('data/dataset.csv')
# display(df.head())

# %% [markdown]
# ## Preprocesado
# Incluye limpieza mínima y funciones reutilizables.

# %%
def preprocess(df):
    """Placeholder: aplica transformaciones esenciales y devuelve df limpio."""
    if df.empty:
        print('DataFrame vacío — no hay datos para preprocesar')
        return df
    # Ejemplo mínimo:
    df = df.copy()
    # df.dropna(subset=['target'], inplace=True)
    return df

# df_clean = preprocess(df)

# %% [markdown]
# ## Modelado y entrenamiento
# Estructura mínima para entrenar y evaluar modelos. Sustituye con tu pipeline.

# %%
def train_sample(X, y):
    """Ejemplo: entrena un estimador simple (placeholder)."""
    from sklearn.model_selection import train_test_split
    from sklearn.ensemble import RandomForestClassifier
    if X is None or y is None:
        print('Entrenamiento: datos no suministrados')
        return None
    X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=SEED)
    model = RandomForestClassifier(random_state=SEED)
    model.fit(X_train, y_train)
    print('Entrenado — evaluar con .score sobre X_val')
    return model

# model = train_sample(X, y)

# %% [markdown]
# ## Resultados
# Incluye visualizaciones y métricas resumidas aquí.

# %% [markdown]
# ## Conclusiones y siguientes pasos
# - Resumen de hallazgos.
# - Ideas para mejorar el baseline (feature engineering, CV, hiperparámetros).
